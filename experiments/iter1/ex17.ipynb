# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../..'))
from experiments.iter1.util.importer_TCN import *
MODEL_PATH = 'model_saves/ex17_model'
nist_path = "../../src/data_preprocess/dataset/NIST_cleaned.csv"

# %%
assert time_horizon > 0, "Time horizon must be a positive integer"
    
df = pd.read_csv(nist_path)

cleaner = TempCleaner(clean_pow_low, clean_in_low, clean_in_high, clean_out_low, clean_out_high, clean_delta_temp)
splitter = StdSplitter(train_days, val_days, test_days)
    
model = TCN(hidden_size, num_layers, input_size, time_horizon, dropout, seq_len)
trainer = TrainerWrapper(L.Trainer, 
                         max_epochs=num_epochs, 
                         callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0, patience=3, verbose=False, mode='min', strict=True)], 
                         gradient_clip_val=gradient_clipping)
optimizer = OptimizerWrapper(optim.Adam, model, lr=learning_rate)

model = DeterministicPipeline.Builder() \
    .add_data(df) \
    .set_cleaner(cleaner) \
    .set_normalizer_class(MinMaxNormalizer) \
    .set_splitter(splitter) \
    .set_sequencer_class(AllTimeSequencer) \
    .set_target_column(TARGET_COLUMN) \
    .set_model(model) \
    .set_optimizer(optimizer) \
    .set_batch_size(batch_size) \
    .set_seq_len(seq_len) \
    .set_worker_num(NUM_WORKERS) \
    .set_error(NRMSE) \
    .set_train_error(RMSE) \
    .set_trainer(trainer) \
    .set_tuner_class(StdTunerWrapper) \
    .build()

model = EnsemblePipeline.Builder() \
        .set_pipeline(model) \
        .set_num_ensembles(num_ensembles) \
        .add_test_error(NRMSE) \
        .add_test_error(NMLSCV) \
        .add_test_error(NMCRPS) \
        .set_horizon_len(time_horizon) \
        .build()

model.fit()
ensemple_val_loss_arr = model.get_validation_loss()
print("VALIDATION LOSS GRAPH")
for loss_arr in ensemple_val_loss_arr:
    plot_loss(loss_arr)
ensemple_train_loss_arr = model.get_training_loss()
print("TRAINING LOSS GRAPH")
for loss_arr in ensemple_train_loss_arr:
    plot_loss(loss_arr)
    
model.save(MODEL_PATH)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 40
#      13 optimizer = OptimizerWrapper(optim.Adam, model, lr=learning_rate)
#      15 model = DeterministicPipeline.Builder() \
#      16     .add_data(df) \
#      17     .set_cleaner(cleaner) \
#    (...)
#      30     .set_tuner_class(StdTunerWrapper) \
#      31     .build()
#      33 model = EnsemblePipeline.Builder() \
#      34         .set_pipeline(model) \
#      35         .set_num_ensembles(num_ensembles) \
#      36         .add_test_error(NRMSE) \
#      37         .add_test_error(NMLSCV) \
#      38         .add_test_error(NMCRPS) \
#      39         .set_horizon_len(time_horizon) \
# ---> 40         .build()
#      42 model.fit()
#      43 ensemple_val_loss_arr = model.get_validation_loss()
#
# File ~/experimentation/src/pipelines/ensemble_pipeline.py:163, in EnsemblePipeline.Builder.build(self)
#     161 def build(self):
#     162     for _ in range(0, self.num_ensembles):
# --> 163         self.pipeline_arr.append(self.sub_pipeline.copy())
#     165     return self.pipeline_class(self.pipeline_arr,
#     166                                self.num_ensembles,
#     167                                self.horizon_len,
#     168                                self.test_error_func_arr)
#
# File ~/experimentation/src/pipelines/deterministic_pipeline.py:17, in DeterministicPipeline.copy(self)
#      16 def copy(self):
# ---> 17     new_model = self.model.copy()
#      18     new_optimizer = self.optimizer.copy(new_model)
#      19     new_trainer_wrapper = self.trainer_wrapper.copy()
#
# File ~/experimentation/src/pipelines/models/tcn.py:32, in TCN.copy(self)
#      31 def copy(self):
# ---> 32     return type(self) (
#      33         self.hidden_size,
#      34         self.num_layers,
#      35         self.input_len,
#      36         self.output_size,
#      37         self.dropout,
#      38         self.seq_len
#      39     )
#
# File ~/experimentation/src/pipelines/models/tcn.py:22, in TCN.__init__(self, hidden_size, num_layers, input_len, horizon_len, dropout, seq_len)
#      18 # Calculate kernel size based of num_layers and seq_len.
#      19 # Kernel size should be big enough so that the receptive field is at least as big as the sequence length
#      20 kernel_size = ceil((2**(num_layers+1) + seq_len - 3) / (2**(num_layers+1) - 2))
# ---> 22 self.tcn = TCNModel(self.input_len, num_channels, kernel_size=kernel_size, dropout=dropout, causal=True, input_shape='NLC', use_skip_connections=True, activation='leaky_relu')
#      23 self.dropout = nn.Dropout(dropout)
#      24 self.fc = nn.Linear(hidden_size, horizon_len)
#
# File ~/experimentation/.venv/lib/python3.12/site-packages/pytorch_tcn/tcn.py:530, in TCN.__init__(self, num_inputs, num_channels, kernel_size, dilations, dilation_reset, dropout, causal, use_norm, activation, kernel_initializer, use_skip_connections, input_shape, embedding_shapes, embedding_mode, use_gate, lookahead, output_projection, output_activation)
#     526     in_channels = num_inputs if i == 0 else num_channels[i-1]
#     527     out_channels = num_channels[i]
#     529     layers += [
# --> 530         TemporalBlock(
#     531             n_inputs=in_channels,
#     532             n_outputs=out_channels,
#     533             kernel_size=kernel_size,
#     534             stride=1,
#     535             dilation=dilation_size,
#     536             dropout=dropout,
#     537             causal=causal,
#     538             use_norm=use_norm,
#     539             activation=activation,
#     540             kerner_initializer=self.kernel_initializer,
#     541             embedding_shapes=self.embedding_shapes,
#     542             embedding_mode=self.embedding_mode,
#     543             use_gate=self.use_gate
#     544             )
#     545         ]
#     547 self.network = nn.ModuleList(layers)
#     549 if self.output_projection is not None:
#
# File ~/experimentation/.venv/lib/python3.12/site-packages/pytorch_tcn/tcn.py:264, in TemporalBlock.__init__(self, n_inputs, n_outputs, kernel_size, stride, dilation, dropout, causal, use_norm, activation, kerner_initializer, embedding_shapes, embedding_mode, use_gate)
#     261 if self.use_gate:
#     262     self.activation1 = nn.GLU(dim=1)
# --> 264 self.dropout1 = nn.Dropout(dropout)
#     265 self.dropout2 = nn.Dropout(dropout)
#     267 self.downsample = nn.Conv1d(n_inputs, n_outputs, 1, padding=0) if n_inputs != n_outputs else None
#
# File ~/experimentation/.venv/lib/python3.12/site-packages/torch/nn/modules/dropout.py:15, in _DropoutNd.__init__(self, p, inplace)
#      13 def __init__(self, p: float = 0.5, inplace: bool = False) -> None:
#      14     super().__init__()
# ---> 15     if p < 0 or p > 1:
#      16         raise ValueError(f"dropout probability has to be between 0 and 1, but got {p}")
#      17     self.p = p
#
# TypeError: '<' not supported between instances of 'Dropout' and 'int'

# %%
from experiments.iter1.util.evaluate import evaluate_model

df = pd.read_csv(nist_path)

cleaner = TempCleaner(clean_pow_low, clean_in_low, clean_in_high, clean_out_low, clean_out_high, clean_delta_temp)
splitter = StdSplitter(train_days, val_days, test_days)
    
model = TCN(hidden_size, num_layers, input_size, time_horizon, dropout, seq_len)
trainer = TrainerWrapper(L.Trainer, 
                         max_epochs=num_epochs, 
                         callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0, patience=3, verbose=False, mode='min', strict=True)], 
                         gradient_clip_val=gradient_clipping)
optimizer = OptimizerWrapper(optim.Adam, model, lr=learning_rate)

model = DeterministicPipeline.Builder() \
    .add_data(df) \
    .set_cleaner(cleaner) \
    .set_normalizer_class(MinMaxNormalizer) \
    .set_splitter(splitter) \
    .set_sequencer_class(AllTimeSequencer) \
    .set_target_column(TARGET_COLUMN) \
    .set_model(model) \
    .set_optimizer(optimizer) \
    .set_batch_size(batch_size) \
    .set_seq_len(seq_len) \
    .set_worker_num(NUM_WORKERS) \
    .set_error(NRMSE) \
    .set_train_error(RMSE) \
    .set_trainer(trainer) \
    .set_tuner_class(StdTunerWrapper) \
    .build()

model = EnsemblePipeline.Builder() \
        .set_pipeline(model) \
        .set_num_ensembles(num_ensembles) \
        .add_test_error(NRMSE) \
        .add_test_error(NMLSCV) \
        .add_test_error(NMCRPS) \
        .set_horizon_len(time_horizon) \
        .build()

model.load(MODEL_PATH)
model.test()

evaluate_model(model, df, splitter, cleaner, TIMESTAMP, POWER, on_limit_w, off_limit_w, consecutive_points, seq_len, time_horizon, TARGET_COLUMN, error, temp_boundary, 0.95)
