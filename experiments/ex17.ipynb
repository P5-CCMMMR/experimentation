# %%
import sys
import os

# Assuming your project directory is one level up from the Jupyter notebook
sys.path.insert(0, os.path.abspath('..'))

import lightning as L
import matplotlib
import numpy as np
import pandas as pd
import multiprocessing
from src.pipelines.trainers.trainerWrapper import TrainerWrapper
from src.util.conditional_early_stopping import ConditionalEarlyStopping
from src.util.flex_error import get_mafe, get_prob_mafe
from src.util.plot import plot_results
from src.util.power_splitter import PowerSplitter
from src.util.error import MNLL, NRMSE

from src.pipelines.cleaners.temp_cleaner import TempCleaner
from src.pipelines.models.gru import GRU
from src.pipelines.normalizers.min_max_normalizer import MinMaxNormalizer
from src.pipelines.sequencers.time_sequencer import TimeSequencer
from src.pipelines.splitters.std_splitter import StdSplitter
from src.pipelines.tuners.std_tuner_wrapper import StdTunerWrapper
from src.pipelines.optimizers.optimizer import OptimizerWrapper

from src.pipelines.deterministic_pipeline import DeterministicPipeline
from src.pipelines.monte_carlo_pipeline import MonteCarloPipeline
from src.pipelines.ensemble_pipeline import EnsemblePipeline
from src.pipelines.probabilistic_pipeline import ProbabilisticPipeline

import torch.optim as optim

matplotlib.use("Agg")

MODEL_PATH = 'model.pth'
NUM_WORKERS = multiprocessing.cpu_count()
TARGET_COLUMN = 2
TIMESTAMP = "Timestamp"
POWER     = "PowerConsumption"

# Hyper parameters
# Model
input_size = 4
time_horizon = 4
hidden_size = 32
num_epochs = 1000
seq_len = 96
num_layers = 2
 
# MC ONLY
inference_samples = 50

# Training
dropout = 0.50
gradient_clipping = 0
early_stopping_threshold = 0.15

num_ensembles = 5

# Flexibility
flex_confidence = 0.90
temp_boundary = 0.1
error = 0

# Controlled by tuner
batch_size = 128
learning_rate = 0.005

# Data Split
train_days = 16
val_days = 2
test_days = 2

# ON / OFF Power Limits
off_limit_w = 100
on_limit_w = 1500

consecutive_points = 3

nist_path = "../src/data_preprocess/dataset/NIST_cleaned.csv"

clean_in_low = 10
clean_in_high = 30
clean_out_low = -50
clean_out_high = 50
clean_pow_low = 0
clean_delta_temp = 15

assert time_horizon > 0, "Time horizon must be a positive integer"
    
df = pd.read_csv(nist_path)

cleaner = TempCleaner(clean_pow_low, clean_in_low, clean_in_high, clean_out_low, clean_out_high, clean_delta_temp)
splitter = StdSplitter(train_days, val_days, test_days)
    
model = GRU(hidden_size, num_layers, input_size, time_horizon, dropout)
trainer = TrainerWrapper(L.Trainer, 
                         max_epochs=num_epochs, 
                         callbacks=[ConditionalEarlyStopping(threshold=early_stopping_threshold)], 
                         gradient_clip_val=gradient_clipping)
optimizer = OptimizerWrapper(optim.Adam, model, lr=learning_rate)

model = MonteCarloPipeline.Builder() \
    .add_data(df) \
    .set_cleaner(cleaner) \
    .set_normalizer_class(MinMaxNormalizer) \
    .set_splitter(splitter) \
    .set_sequencer_class(TimeSequencer) \
    .set_target_column(TARGET_COLUMN) \
    .set_model(model) \
    .set_optimizer(optimizer) \
    .set_batch_size(batch_size) \
    .set_seq_len(seq_len) \
    .set_worker_num(NUM_WORKERS) \
    .set_error(NRMSE) \
    .set_trainer(trainer) \
    .set_tuner_class(StdTunerWrapper) \
    .set_inference_samples(inference_samples) \
    .set_test_error(MNLL) \
    .build()

model = EnsemblePipeline.Builder() \
        .set_pipeline(model) \
        .set_num_ensembles(num_ensembles) \
        .build()

model.fit()
model.test()

plot_results(model.get_predictions(), model.get_actuals(), model.get_timestamps())

model.eval()

ps = PowerSplitter(splitter.get_test(cleaner.clean(df)), TIMESTAMP, POWER)

on_df = ps.get_mt_power(on_limit_w, consecutive_points)
off_df = ps.get_lt_power(off_limit_w, consecutive_points)

on_data = np.array(on_df)
off_data = np.array(off_df)

print("Calculating mafe...")
if (isinstance(model, ProbabilisticPipeline)):
    print("PROB MAFE ON:", get_prob_mafe(on_data, model, seq_len, error, temp_boundary, time_horizon, TARGET_COLUMN, flex_confidence))
    print("PROB MAFE OFF:", get_prob_mafe(off_data, model, seq_len, error, temp_boundary, time_horizon, TARGET_COLUMN, flex_confidence))
else:
    print("MAFE ON:", get_mafe(on_data, model, seq_len, error, temp_boundary, time_horizon, TARGET_COLUMN))
    print("MAFE OFF:", get_mafe(off_data, model, seq_len, error, temp_boundary, time_horizon, TARGET_COLUMN))
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Finding best initial lr:   0%|          | 0/100 [00:00<?, ?it/s]
#
#
#
#
#
#
# Finding best initial lr:   1%|          | 1/100 [00:00<00:58,  1.68it/s]
#
#
#
#
#
#
#
# Finding best initial lr:   3%|▎         | 3/100 [00:00<00:21,  4.41it/s]
#
#
# Finding best initial lr:   5%|▌         | 5/100 [00:00<00:13,  7.11it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Finding best initial lr:   7%|▋         | 7/100 [00:01<00:15,  6.02it/s]
#
#
#
#
# Finding best initial lr:   9%|▉         | 9/100 [00:01<00:11,  8.11it/s]
#
#
#
#
#
# Finding best initial lr:  11%|█         | 11/100 [00:01<00:08,  9.91it/s]
#
#
#
#
#
# Finding best initial lr:  14%|█▍        | 14/100 [00:01<00:06, 12.88it/s]
#
#
#
#
#
# Finding best initial lr:  16%|█▌        | 16/100 [00:01<00:05, 14.30it/s]
#
#
#
#
#
# Finding best initial lr:  19%|█▉        | 19/100 [00:01<00:05, 16.01it/s]
#
#
#
# Finding best initial lr:  21%|██        | 21/100 [00:02<00:04, 16.74it/s]
#
#
#
#
#
# Finding best initial lr:  23%|██▎       | 23/100 [00:02<00:04, 17.25it/s]
#
#
# Finding best initial lr:  25%|██▌       | 25/100 [00:02<00:04, 15.89it/s]
#
#
#
#
#
# Finding best initial lr:  27%|██▋       | 27/100 [00:02<00:04, 15.13it/s]
#
#
#
#
#
# Finding best initial lr:  29%|██▉       | 29/100 [00:02<00:05, 14.01it/s]
#
#
#
#
#
# Finding best initial lr:  31%|███       | 31/100 [00:02<00:04, 13.85it/s]
#
#
#
#
#
# Finding best initial lr:  33%|███▎      | 33/100 [00:02<00:04, 14.65it/s]
#
#
#
#
#
# Finding best initial lr:  35%|███▌      | 35/100 [00:03<00:04, 14.88it/s]
#
#
#
#
#
# Finding best initial lr:  37%|███▋      | 37/100 [00:03<00:04, 15.14it/s]
#
#
#
#
#
# Finding best initial lr:  39%|███▉      | 39/100 [00:03<00:04, 14.97it/s]
#
#
#
#
#
# Finding best initial lr:  41%|████      | 41/100 [00:03<00:04, 14.60it/s]
#
#
#
#
#
# Finding best initial lr:  43%|████▎     | 43/100 [00:03<00:04, 14.15it/s]
#
#
#
#
#
# Finding best initial lr:  45%|████▌     | 45/100 [00:03<00:04, 13.60it/s]
#
#
#
#
#
#
#
#
# Finding best initial lr:  47%|████▋     | 47/100 [00:03<00:03, 13.42it/s]
#
#
#
#
#
# Finding best initial lr:  49%|████▉     | 49/100 [00:04<00:03, 12.97it/s]
#
#
#
#
#
#
#
# Finding best initial lr:  51%|█████     | 51/100 [00:04<00:03, 12.42it/s]
#
#
#
#
#
# Finding best initial lr:  53%|█████▎    | 53/100 [00:04<00:03, 13.00it/s]
#
#
#
#
#
# Finding best initial lr:  55%|█████▌    | 55/100 [00:04<00:03, 13.53it/s]
#
#
#
#
#
# Finding best initial lr:  57%|█████▋    | 57/100 [00:04<00:03, 13.68it/s]
#
#
#
#
#
# Finding best initial lr:  59%|█████▉    | 59/100 [00:04<00:02, 14.42it/s]
#
#
#
#
#
# Finding best initial lr:  61%|██████    | 61/100 [00:04<00:02, 14.75it/s]
#
#
#
#
#
# Finding best initial lr:  63%|██████▎   | 63/100 [00:05<00:02, 14.44it/s]
#
#
#
#
#
# Finding best initial lr:  65%|██████▌   | 65/100 [00:05<00:02, 14.34it/s]
#
#
#
#
#
# Finding best initial lr:  67%|██████▋   | 67/100 [00:05<00:02, 14.84it/s]
#
#
#
#
#
#
# Finding best initial lr:  69%|██████▉   | 69/100 [00:05<00:02, 15.05it/s]
#
#
#
#
#
# Finding best initial lr:  71%|███████   | 71/100 [00:05<00:01, 15.90it/s]
#
# `Trainer.fit` stopped: `max_steps=100` reached.
# Finding best initial lr: 100%|██████████| 100/100 [00:04<00:00, 22.93it/s]
# Learning rate set to 1.5848931924611133e-07
# Restoring states from the checkpoint path at /home/vind/P5/experimentation/experiments/.lr_find_aa0ead0f-9077-4436-864b-e0212105e20c.ckpt
# Restored all states from the checkpoint at /home/vind/P5/experimentation/experiments/.lr_find_aa0ead0f-9077-4436-864b-e0212105e20c.ckpt
# `Trainer.fit` stopped: `max_steps=100` reached.
# Finding best initial lr: 100%|██████████| 100/100 [00:04<00:00, 22.43it/s]
# Learning rate set to 1.5848931924611133e-07
# Restoring states from the checkpoint path at /home/vind/P5/experimentation/experiments/.lr_find_1290aa3c-1282-4d08-a664-67f1cff13bed.ckpt
# Restored all states from the checkpoint at /home/vind/P5/experimentation/experiments/.lr_find_1290aa3c-1282-4d08-a664-67f1cff13bed.ckpt
# `Trainer.fit` stopped: `max_steps=100` reached.
# Finding best initial lr: 100%|██████████| 100/100 [00:04<00:00, 21.67it/s]
# Learning rate set to 1.5848931924611133e-07
# Restoring states from the checkpoint path at /home/vind/P5/experimentation/experiments/.lr_find_97b90780-dbfa-4515-b918-016d62f9e9ec.ckpt
# Restored all states from the checkpoint at /home/vind/P5/experimentation/experiments/.lr_find_97b90780-dbfa-4515-b918-016d62f9e9ec.ckpt
# `Trainer.fit` stopped: `max_steps=100` reached.
# Finding best initial lr: 100%|██████████| 100/100 [00:04<00:00, 21.66it/s]
# Learning rate set to 1.5848931924611133e-07
# Restoring states from the checkpoint path at /home/vind/P5/experimentation/experiments/.lr_find_be55f970-78fa-4724-beb2-ffd5a1c7e519.ckpt
# Restored all states from the checkpoint at /home/vind/P5/experimentation/experiments/.lr_find_be55f970-78fa-4724-beb2-ffd5a1c7e519.ckpt
# `Trainer.fit` stopped: `max_steps=100` reached.
# Finding best initial lr: 100%|██████████| 100/100 [00:04<00:00, 20.86it/s]
# Learning rate set to 1.5848931924611133e-07
# Restoring states from the checkpoint path at /home/vind/P5/experimentation/experiments/.lr_find_6815f3f6-fedf-436c-83e5-c6efe9fd6040.ckpt
# Restored all states from the checkpoint at /home/vind/P5/experimentation/experiments/.lr_find_6815f3f6-fedf-436c-83e5-c6efe9fd6040.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_steps=3` reached.
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 2 succeeded, trying batch size 4
# Batch size 2 succeeded, trying batch size 4
# `Trainer.fit` stopped: `max_steps=3` reached.
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 2 succeeded, trying batch size 4
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 2 succeeded, trying batch size 4
# Batch size 2 succeeded, trying batch size 4
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 4 succeeded, trying batch size 8
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 4 succeeded, trying batch size 8
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 4 succeeded, trying batch size 8
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 4 succeeded, trying batch size 8
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 4 succeeded, trying batch size 8
# `Trainer.fit` stopped: `max_steps=3` reached.
# `Trainer.fit` stopped: `max_steps=3` reached.
# `Trainer.fit` stopped: `max_steps=3` reached.
# `Trainer.fit` stopped: `max_steps=3` reached.
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 8 succeeded, trying batch size 16
# Batch size 8 succeeded, trying batch size 16
# Batch size 8 succeeded, trying batch size 16
# Batch size 8 succeeded, trying batch size 16
# Batch size 8 succeeded, trying batch size 16
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 16 succeeded, trying batch size 32
# `Trainer.fit` stopped: `max_steps=3` reached.
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 16 succeeded, trying batch size 32
# Batch size 16 succeeded, trying batch size 32
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 16 succeeded, trying batch size 32
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 16 succeeded, trying batch size 32
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 32 succeeded, trying batch size 64
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 32 succeeded, trying batch size 64
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 32 succeeded, trying batch size 64
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 32 succeeded, trying batch size 64
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 32 succeeded, trying batch size 64
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 64 succeeded, trying batch size 128
# `Trainer.fit` stopped: `max_steps=3` reached.
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 64 succeeded, trying batch size 128
# `Trainer.fit` stopped: `max_steps=3` reached.
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 64 succeeded, trying batch size 128
# Batch size 64 succeeded, trying batch size 128
# Batch size 64 succeeded, trying batch size 128
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 128 succeeded, trying batch size 256
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 128 succeeded, trying batch size 256
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 128 succeeded, trying batch size 256
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 128 succeeded, trying batch size 256
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 128 succeeded, trying batch size 256
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 256 succeeded, trying batch size 512
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 256 succeeded, trying batch size 512
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 256 succeeded, trying batch size 512
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 256 succeeded, trying batch size 512
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 256 succeeded, trying batch size 512
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 512 succeeded, trying batch size 1024
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 512 succeeded, trying batch size 1024
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 512 succeeded, trying batch size 1024
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 512 succeeded, trying batch size 1024
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 512 succeeded, trying batch size 1024
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 1024 succeeded, trying batch size 2048
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 1024 succeeded, trying batch size 2048
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 1024 succeeded, trying batch size 2048
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 1024 succeeded, trying batch size 2048
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 1024 succeeded, trying batch size 2048
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 2048 succeeded, trying batch size 4096
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 2048 succeeded, trying batch size 4096
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 2048 succeeded, trying batch size 4096
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 2048 succeeded, trying batch size 4096
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 2048 succeeded, trying batch size 4096
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 4096 succeeded, trying batch size 8192
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 4096 succeeded, trying batch size 8192
# `Trainer.fit` stopped: `max_steps=3` reached.
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 4096 succeeded, trying batch size 8192
# Batch size 4096 succeeded, trying batch size 8192
# `Trainer.fit` stopped: `max_steps=3` reached.
# Batch size 4096 succeeded, trying batch size 8192
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
